# %%
import numpy as np
import pandas as pd

import scipy.stats as stats

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 定义函数和分布

# %%
# 定义f(x)
def f_x(x):
    return 1/(1 + np.exp(-x))

# %%
fig = plt.figure(figsize=(8,2))
ax = fig.add_subplot(1,1,1)

# 绘制图形
x = np.linspace(0, 4, 100)
ax.plot(x, f_x(x), 'b.', label=r'$\frac{1}{1+exp(-x)}$')

ax.legend(fontsize=17)

# %% [markdown]
# ## 实验一
#
# 第一个实验两个分布比较类似.
#
# - p(x)的均值3.5, 方差1;
# - q(x)的均值3, 方差1;

# %%
# p(x)
mu_target = 3.5
sigma_target = 1
p_x = [np.random.normal(mu_target, sigma_target) for _ in range(3000)]

# q(x)
mu_appro = 3
sigma_appro = 1
q_x = [np.random.normal(mu_appro, sigma_appro) for _ in range(3000)]

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,1,1)

# 画出两个分布的图像
sns.distplot(p_x, label="distribution $p(x)$")
sns.distplot(q_x, label="distribution $q(x)$")

plt.title("Distributions", size=16)
plt.legend()

# %%
# 当x~p(x)时, E[f(x)]
np.mean([f_x(i) for i in p_x])
# Out:
# 0.9552799855749114

# %%
# 当x~q(x), E[f(x)] = mean(p(x)/q(x)*f(x))
p_pdf = stats.norm(mu_target, sigma_target)
q_pdf = stats.norm(mu_appro, sigma_appro)

print(np.mean([p_pdf.pdf(i)/q_pdf.pdf(i) * f_x(i) for i in q_x]), np.var([p_pdf.pdf(i)/q_pdf.pdf(i) * f_x(i) for i in q_x]))
# Out:
# 0.9657395577637271 0.32068092292839756

# %% [markdown]
# ## 实验二
#
# 第二个实验两个分布相差比较远.
#
# - p(x)的均值3.5, 方差1;
# - q(x)的均值1, 方差1;

# %%
# p(x)
mu_target = 3.5
sigma_target = 1
p_x = [np.random.normal(mu_target, sigma_target) for _ in range(3000)]

# q(x)
mu_appro = 1
sigma_appro = 1
q_x = [np.random.normal(mu_appro, sigma_appro) for _ in range(3000)]

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,1,1)

# 画出两个分布的图像
sns.distplot(p_x, label="distribution $p(x)$")
sns.distplot(q_x, label="distribution $q(x)$")

plt.title("Distributions", size=16)
plt.legend()

# %%
# 当x~p(x)时, E[f(x)]
np.mean([f_x(i) for i in p_x])
# Out:
# 0.9564292996158023

# %%
# 采样数量=3000
# 当x~q(x), E[f(x)] = mean(p(x)/q(x)*f(x))
total = 3000
p_x = [np.random.normal(mu_target, sigma_target) for _ in range(total)]
q_x = [np.random.normal(mu_appro, sigma_appro) for _ in range(total)]

p_pdf = stats.norm(mu_target, sigma_target)
q_pdf = stats.norm(mu_appro, sigma_appro)

print(np.mean([p_pdf.pdf(i)/q_pdf.pdf(i) * f_x(i) for i in q_x]), np.var([p_pdf.pdf(i)/q_pdf.pdf(i) * f_x(i) for i in q_x]))
# Out:
# 0.8034491280497017 29.634697958927116

# %%
# 采样数量5000
# 当x~q(x), E[f(x)] = mean(p(x)/q(x)*f(x))
total = 5000
p_x = [np.random.normal(mu_target, sigma_target) for _ in range(total)]
q_x = [np.random.normal(mu_appro, sigma_appro) for _ in range(total)]

p_pdf = stats.norm(mu_target, sigma_target)
q_pdf = stats.norm(mu_appro, sigma_appro)

print(np.mean([p_pdf.pdf(i)/q_pdf.pdf(i) * f_x(i) for i in q_x]), np.var([p_pdf.pdf(i)/q_pdf.pdf(i) * f_x(i) for i in q_x]))
# Out:
# 0.7675237384857081 24.031753330814613

# %%
# 当x~q(x), E[f(x)] = mean(p(x)/q(x)*f(x))
# 采样数量=10000
total = 10000
p_x = [np.random.normal(mu_target, sigma_target) for _ in range(total)]
q_x = [np.random.normal(mu_appro, sigma_appro) for _ in range(total)]

p_pdf = stats.norm(mu_target, sigma_target)
q_pdf = stats.norm(mu_appro, sigma_appro)

print(np.mean([p_pdf.pdf(i)/q_pdf.pdf(i) * f_x(i) for i in q_x]), np.var([p_pdf.pdf(i)/q_pdf.pdf(i) * f_x(i) for i in q_x]))
# Out:
# 0.8740549731931447 69.76793572044657

# %%
# 当x~q(x), E[f(x)] = mean(p(x)/q(x)*f(x))
# 采样数量=100000
total = 100000
p_x = [np.random.normal(mu_target, sigma_target) for _ in range(total)]
q_x = [np.random.normal(mu_appro, sigma_appro) for _ in range(total)]

p_pdf = stats.norm(mu_target, sigma_target)
q_pdf = stats.norm(mu_appro, sigma_appro)

print(np.mean([p_pdf.pdf(i)/q_pdf.pdf(i) * f_x(i) for i in q_x]), np.var([p_pdf.pdf(i)/q_pdf.pdf(i) * f_x(i) for i in q_x]))
# Out:
# 0.864169192167605 79.40022261216386
